# %%
import csv
import mysql.connector as connection

# %% [markdown]
# ### full code to insert values

# %%
import mysql.connector as connection
import pandas as pandas
import csv

try:
    mydb = connection.connect(host="localhost", user="root", passwd="Datascientist@1949",use_pure=True)
    #check if the connection is established
    print(mydb.is_connected())
    #create a new database
    query = "Create database Mydata;"
    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Database Created!!")
    mydb.close() #close the connection

    #Establish a new connection to the database created above
    mydb = connection.connect(host="localhost", database = 'Mydata',user="root", passwd="mysql", use_pure=True)

    #create a new table to store glass data
    query = "CREATE TABLE IF NOT EXISTS Mydata (a INT(10),b float(10,5), c float(10,5), d float(10,5),e float(10,5),f float(10,5), g float(10,5), h float(10,5), i float(10,5), j float(10,5), k INT(5), l int(10) ,m int(10),n int(10))"
    cursor = mydb.cursor()  # create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")

    #read from the file
    with open("C:/Users/Ravi/Downloads/carbon_nanotubes.csv","r") as csv_file:
        
        next(csv_file)
        file = csv.reader(csv_file , delimiter = ";")
        for i in file:
            
            print("," .join(i))
            
            cursor.execute("INSERT INTO Mydata.carbondetail values ({values})".format(values=",".join(i)))
        
    
    print("Values inserted!!")
    mydb.commit()
    cursor.close()
    mydb.close()

except Exception as e:
    #mydb.close()
    print(str(e))
# Out:
# True
# 1007 (HY000): Can't create database 'mydata'; database exists

# %% [markdown]
# ####  connectiing through database which was created earlier

# %%
mydb = connection.connect(host="localhost", database = 'Mydata',user="root", passwd="Datascientist@1949",use_pure=True)

# %%
print(mydb.is_connected())
# Out:
# True

# %%
cur.execute("create table ravivi.table(aa int,bb float,cc float,dd float,ee float,ff float,gg float)")

# %%
cursor = mydb.cursor()

# %% [markdown]
# ### inserting csv file into mysql database

# %%
with open("C:/Users/Ravi/Downloads/carbon_nanotubes.csv","r") as csv_file:
    next(csv_file)
    file = csv.reader(csv_file , delimiter = ";")
    for i in file:
        print("," .join(i))
        cursor.execute("INSERT INTO Mydata.carbondetail values ({values})".format(values=",".join(i)))
        
mydb.commit()
# Out:
# 2,1,0,679005,0,701318,0,017033,0,721039,0,730232,0,017014
# 2,1,0,717298,0,642129,0,231319,0,738414,0,65675,0,232369
# 2,1,0,489336,0,303751,0,088462,0,477676,0,263221,0,088712
# 2,1,0,413957,0,632996,0,040843,0,408823,0,657897,0,039796
# 2,1,0,334292,0,543401,0,15989,0,303349,0,558807,0,157373
# 2,1,0,510664,0,696249,0,255128,0,496977,0,725608,0,25597
# 2,1,0,413957,0,632996,0,374176,0,390878,0,657645,0,374735
# 2,1,0,712552,0,55479,0,112271,0,750056,0,561494,0,114944
# 2,1,0,320995,0,298682,0,1837,0,281301,0,261433,0,182779
# 2,1,0,394742,0,279367,0,302747,0,35086,0,2335,0,302196
# 2,1,0,282702,0,357871,0,397985,0,229138,0,328729,0,398581
# 2,1,0,320995,0,298682,0,517033,0,278752,0,269615,0,51733
# 2,1,0,605258,0,720633,0,469414,0,613415,0,760009,0,469452
# 2,1,0,510664,0,696249,0,588462,0,521991,0,736991,0,588946
# 2,1,0,679005,0,701318,0,6837,0,718811,0,738577,0,68244
# 2,1,0,605258,0,720633,0,802747,0,649178,0,766301,0,80193
# ...

# %%
l = ["1;2;3" ,"3" ,"0,252525" ,"0,23424324"]

# %%
l1 = []

# %%
for i in l:
    for j in i:
        l1.append(l)
        print(j , end = " ")
# Out:
# 1 ; 2 ; 3 3 0 , 2 5 2 5 2 5 0 , 2 3 4 2 4 3 2 4

# %%
for i in l:
    for j in i:
        print(j , end = "")
# Out:
# 1;2;330,2525250,23424324

# %%
l1
# Out:
# [['1;2;3', '3']]

# %%
for i in l:
    print(i)
# Out:
# 1;2;3
# 3
# 0,252525
# 0,23424324
